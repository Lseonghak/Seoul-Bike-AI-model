# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
cd /gdrive/MyDrive/seoul_bike_ai_model/
# Out:
# /gdrive/MyDrive/seoul_bike_ai_model

# %%
# !git remote remove origin
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !echo "따릉이(정리)" >> README.md
# !git init
# !git add README.md
# !git add .
# !git config --global user.email "dltjdgkr6220@gmail.com"
# !git config --global user.name "Lseonghak"
# !git commit -m "first commit"
# !git branch -M main
# !git remote remove origin
# Out:
# Initialized empty Git repository in /gdrive/MyDrive/seoul_bike_ai_model/.git/
# [master (root-commit) 63c6031] first commit
#  5 files changed, 3 insertions(+)
#  create mode 100644 "220122\341\204\203\341\205\265\341\206\270\341\204\205\341\205\245\341\204\202\341\205\265\341\206\274_\341\204\216\341\205\254\341\204\214\341\205\251\341\206\274\341\204\207\341\205\241\341\206\257\341\204\221\341\205\255(0800).pptx"
#  create mode 100644 README.md
#  create mode 100644 data.zip
#  create mode 100644 for_git_commit.ipynb
#  create mode 100644 "\341\204\204\341\205\241\341\204\205\341\205\263\341\206\274\341\204\213\341\205\265(\341\204\214\341\205\245\341\206\274\341\204\205\341\205\265)"

# %%
# !git remote remove origin
# !git remote add origin http://Lseonghak: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@github.com/Lseonghak/Seoul-Bike-AI-model.git
# !git push -u origin main
# Out:
# fatal: No such remote: origin
# remote: Invalid username or password.
# fatal: Authentication failed for 'http://Lseonghak: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@github.com/Lseonghak/Seoul-Bike-AI-model.git/'
